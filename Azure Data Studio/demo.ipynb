-- %% [markdown]
-- #  Azure Data Studio Demos 👨🏻‍🔬
-- On this demo we will see the basic usage of the tool and some other cool options available.
-- We will check how:
--
-- - Basic navigation and options
-- - Create custom code snippets
-- - Create data insights (custom widgets)
-- - Creating and using Notebooks **(ohh wait! this is a notebook)**
-- - Creating your own extensions *(dashboard if time permits)*
--
-- ## 📌 Basic navigation and options
-- -----
--
-- To access the command palette, press **F1** or  **Ctrl + Shift + P**
--
-- - Try the **Zen mode**!
--
-- You can check all the actions available there *(Also actions from installed extensions)*
--
-- Connect to any available connection or create a new one. Right click on the server and click on Manage to access the dashboard.
--
-- Now open 📝 *script1.sql* file to see the editor basic options
--
-- You can also create files directly on the explorer menu via right click options **(try to create ScriptN.sql file and then delete it)**
--
-- Navigate to the extensions tab on the left side, you can add new extensions there and administer existing ones
--
--
--
-- ## 📌 Create custom code snippets
-- ---
--
-- Open 📝 *Script2.sql* file.
--
-- follow the instructions included on it.
--
--
-- ## 📌 Create custom widgets
-- ---
-- Open 📝 *Script3.sql* file.
--
-- Follow the instructions included on it.
--
-- Delete the custom widget as we will create a extension of it later!
--
-- ## 📌 Creating and using Notebooks
-- ---
-- Open 📝 *NotebookDemo.ipynb* file
-- follow the instructions included on it.
--
-- ## 📌 Creating your own extension
-- ---
-- This is a more advanced topic, so we will show you how to create an extension really quick.
-- if you want to know more about extensions, and follow a more detailed tutorial, please check my articles at:
--
-- How to create a Dashboard extension > https://www.mssqltips.com/sqlservertip/6023/creating-dashboard-extensions-for-azure-data-studio/
--
-- How to create a Typescript extension > https://www.mssqltips.com/sqlservertip/6047/create-azure-data-studio-extension-with-typescript/
--
-- For now, we will take our Widget demo and packet it as an extension.
--
-- Prerequisites **(you can check how to install those on any of my articles)**:
--  - Node.js
--  - VSCode
--  - Azure Data Studio debug extension for VSCode
--  - Yeoman Extension generator (using npm)
--  - VSCE package (using npm), this is used for packaging the .vsix file
--
-- Steps:
--
-- - Open VSCode
-- - On a terminal run: <br/><b>yo azuredatastudio</b>
-- - Select dashboard extension type
-- - Complete the wizard with the required info
-- - Navigate to your template by running:
--     <br/><b>cd yourExtensionName<br/>
--      code .</b>
--
-- - Open query.sql file and add your query (for our example contents of Script3.sql)
-- - Open package.json file, navigate to 📝 **dashboard.insights** and modify the **type** property with the contents of the **type** property on our widget
-- - Open launch.json file, check if *azuredatastudio* is set on **"runtimeExecutable"**
-- - Debug it!
-- - When you are ok with the extension, we will create the .vsix file
-- - Update readme.md to skip warnings created by vsce
-- - open package.json and update the vscode engine to a lower number (if no, the vsix import will fail)
-- - Run the following command on a terminal:
--     <br/><b>vsce packate</b>
-- - If everything is ok, you will be able to import the created .vsix file into Azure Data Studio.
--
--
-- ---
--
-- ## And that is all for today! hopefully we got until here without bugs or issues 😊
--
-- ## Any question?
